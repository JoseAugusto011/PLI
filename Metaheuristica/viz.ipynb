# %%
import pandas as pd

df = pd.read_csv('resultados_heuristica_len_5.csv')
df.head()
# Out:
#    qtd_times                                  lahc_grid_results  lahc_custos  \
# 0          6  [[6, -4, -2, 5, 3], [-1, -6, -4, 5, -3], [2, 4...        11332
# 1         13  [[-11, -3, -5, 10, 9, -7, 12, -8, 6, 4, -2, -1...        35347
# 2         14  [[-6, -2, -10, -14, -3, 9, 11, 13, 4, -12, -8,...        44058
# 3          7  [[5, 6, 3, 2, -7, -4], [-5, 4, 7, 3, 6, 1], [5...        12944
# 4         10  [[-10, 6, -2, -7, -9, -3, 8, -4, -5], [-9, 6, ...        22520
#
#    lahc_tempo                                    sa_grid_results  sa_custos  \
# 0    0.018702  [[-5, 6, 4, 3, -2], [-5, 3, 1, -4, 6], [2, -1,...       9142
# 1    0.051383  [[-6, -2, -3, -13, -5, 7, 8, -4, -9, -12, -11,...      30606
# 2    0.058268  [[-5, 8, 10, -9, 2, -6, -14, 11, 12, -13, 3, -...      30140
# 3    0.017110  [[5, 4, 6, 2, -3, -7], [6, 7, 4, -5, -1, 3], [...      12207
# 4    0.033207  [[9, 5, -3, -2, -10, -6, 4, 8, -7], [-8, -1, -...      20726
#
# ...
